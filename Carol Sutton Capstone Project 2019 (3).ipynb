# %% [markdown]
# # This is the Capstone Project from the Course
#
# ## This is where I will create the elements of code that I need.  These include
# #### 1. Geographical data
# #### 2. Situation information
#
# ###  This is the output from the first exercise

# %%
print ( 'Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# ## This is were I import all the libraries

# %%
import pandas as pd
import numpy as np
